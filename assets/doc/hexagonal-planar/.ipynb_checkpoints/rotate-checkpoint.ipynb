# %%
import os
import shutil
from copy import deepcopy
import numpy as np
from angstrom import Molecule, Trajectory
from angstrom.visualize import render
from angstrom.visualize.blender import Blender
from IPython.display import Image
from angstrom.cli.tools import rotation
from angstrom.geometry.quaternion import Quaternion

# %%
intersections_dir = "/Users/kbsezginel/kbs/git/lemongrove.github.io/assets/molecules/intersections"
xyz_file = os.path.join(intersections_dir, "Hexagonal-planar-n4-m4.xyz")
mol = Molecule(read=xyz_file)
z_align = [328, 346]
c1, c2 = (mol.coordinates[z] for z in z_align)
mol.align(c2 - c1, [0, 0, 1])
y_align = [325, 328]
c1, c2 = (mol.coordinates[y] for y in y_align)
mol.align(c2 - c1, [0, 1, 0])
x_align = [329, 327]
c1, c2 = (mol.coordinates[x] for x in x_align)
mol.align(c2 - c1, [1, 0, 0])

mol.rotate('x', np.pi / 250)
mol.rotate('y', - np.pi / 300)
# negative is clockwise
# mol.rotate('y', - np.pi / 300)
mol.center([0, 0, 0])
mol.write('hexagonal-planar-align.xyz')

# mol.center([0, 0, -10])
# mol.write('hexagonal-planar-align.xyz')

# %%
# test render
mol.center([0, 0, -15])
render(mol, renderer=blender_traj())
Image('angstrom.png')
# Out:
# Rendering Hexagonal-planar-n4-m4 image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/angstrom

# %%
def blender_traj():
    blend = Blender()
    blend.config["executable"] = '/Applications/Blender.app/Contents/MacOS/Blender'
    blend.config['camera']['type'] = 'PERSP'
    blend.config['camera']['zoom'] = 30
    # blend.config['save'] = 'octahedtal.blend'
    blend.config['pdb']['use_center'] = False
    blend.config['pdb']['scale_ballradius'] = 0.2
    blend.config['resolution'] = (800, 800)
    blend.config['img_file'] = 'trigonal'
    blend.config['vid_file'] = 'trigonal'
    blend.config['light'] = 5000
    return blend

# %%
n_frames = 30
angle = 360
for drx in ['x', 'y', 'z']:
    mol = Molecule(read='hexagonal-planar-align.xyz')
    mol.center([0, 0, -16])
    traj_sine = rotation(mol, n_frames, angle, drx, interpolation='sine', center=True, verbose=False)
    blend = blender_traj()
    print(f'rendering {drx}')
    render(traj_sine, renderer=blend)
    # Move images
    images = [f"{i}.png" for i in range(n_frames)]
    drx_dir = f'{drx}'
    os.makedirs(drx_dir, exist_ok=True)
    for img in images:
        shutil.move(img, os.path.join(drx_dir, img))
# Out:
# rendering x
# Rendering 31 images with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/0.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/1.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/2.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/3.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/4.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/5.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/6.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/7.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/8.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/9.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/10.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/11.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/12.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/13.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/14.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/15.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/16.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/17.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/18.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/19.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/20.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/21.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/22.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/23.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/24.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/25.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/26.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/27.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/28.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/29.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/30.png
# Rendering hexagonal-planar-align video with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/angstrom
# rendering y
# Rendering 31 images with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/0.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/1.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/2.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/3.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/4.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/5.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/6.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/7.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/8.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/9.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/10.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/11.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/12.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/13.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/14.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/15.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/16.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/17.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/18.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/19.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/20.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/21.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/22.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/23.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/24.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/25.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/26.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/27.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/28.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/29.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/30.png
# Rendering hexagonal-planar-align video with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/angstrom
# rendering z
# Rendering 31 images with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/0.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/1.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/2.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/3.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/4.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/5.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/6.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/7.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/8.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/9.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/10.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/11.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/12.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/13.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/14.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/15.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/16.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/17.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/18.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/19.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/20.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/21.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/22.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/23.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/24.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/25.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/26.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/27.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/28.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/29.png
# Rendering Molecule image with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/30.png
# Rendering hexagonal-planar-align video with Blender -> /Users/kbsezginel/kbs/git/lemongrove.github.io/assets/doc/hexagonal-planar/angstrom

# %%
blend.config
# Out:
# {'pdb': {'filepath': '',
#   'use_center': True,
#   'use_camera': False,
#   'use_light': False,
#   'ball': '0',
#   'mesh_azimuth': 32,
#   'mesh_zenith': 32,
#   'scale_ballradius': 0.5,
#   'scale_distances': 1,
#   'atomradius': '2',
#   'use_sticks': True,
#   'use_sticks_type': '0',
#   'sticks_subdiv_view': 2,
#   'sticks_subdiv_render': 2,
#   'sticks_sectors': 20,
#   'sticks_radius': 0.25,
#   'sticks_unit_length': 0.05,
#   'use_sticks_color': True,
#   'use_sticks_smooth': True,
#   'use_sticks_bonds': False,
#   'sticks_dist': 1.1,
#   'use_sticks_one_object': True,
#   'use_sticks_one_object_nr': 200},
#  'img_file': '',
#  'img_format': 'PNG',
#  'vid_file': 'hexagonal-planar-3d',
#  'vid_format': 'AVI_JPEG',
#  'images': ['3d/0.png',
#   '3d/1.png',
#   '3d/2.png',
#   '3d/3.png',
#   '3d/4.png',
#   '3d/5.png',
#   '3d/6.png',
#   '3d/7.png',
#   '3d/8.png',
#   '3d/9.png',
#   '3d/10.png',
#   '3d/11.png',
#   '3d/12.png',
#   '3d/13.png',
#   '3d/14.png',
#   '3d/15.png',
#   '3d/16.png',
#   '3d/17.png',
#   '3d/18.png',
#   '3d/19.png',
#   '3d/20.png',
#   '3d/21.png',
#   '3d/22.png',
#   '3d/23.png',
#   '3d/24.png',
#   '3d/25.png',
#   '3d/26.png',
#   '3d/27.png',
#   '3d/28.png',
#   '3d/29.png',
#   '3d/30.png',
#   '3d/31.png',
#   '3d/32.png',
#   '3d/33.png',
#   '3d/34.png',
#   '3d/35.png',
#   '3d/36.png',
#   '3d/37.png',
#   '3d/38.png',
#   '3d/39.png',
#   '3d/40.png',
#   '3d/41.png',
#   '3d/42.png',
#   '3d/43.png',
#   '3d/44.png',
#   '3d/45.png',
#   '3d/46.png',
#   '3d/47.png',
#   '3d/48.png',
#   '3d/49.png',
#   '3d/50.png',
#   '3d/51.png',
#   '3d/52.png',
#   '3d/53.png',
#   '3d/54.png',
#   '3d/55.png',
#   '3d/56.png',
#   '3d/57.png',
#   '3d/58.png',
#   '3d/59.png',
#   '3d/60.png',
#   '3d/61.png',
#   '3d/62.png',
#   '3d/63.png',
#   '3d/64.png',
#   '3d/65.png',
#   '3d/66.png',
#   '3d/67.png',
#   '3d/68.png',
#   '3d/69.png',
#   '3d/70.png',
#   '3d/71.png',
#   '3d/72.png',
#   '3d/73.png',
#   '3d/74.png',
#   '3d/75.png',
#   '3d/76.png',
#   '3d/77.png',
#   '3d/78.png',
#   '3d/79.png',
#   '3d/80.png',
#   '3d/81.png',
#   '3d/82.png',
#   '3d/83.png',
#   '3d/84.png',
#   '3d/85.png',
#   '3d/86.png',
#   '3d/87.png',
#   '3d/88.png',
#   '3d/89.png'],
#  'fps': 17,
#  'camera': {'location': [0, 0, 10],
#   'rotation': [0, 0, 0],
#   'type': 'ORTHO',
#   'zoom': 20},
#  'light': 2000.0,
#  'resolution': (800, 800),
#  'colors': {'Carbon': (0.05, 0.05, 0.05, 1.0),
#   'Hydrogen': (1.0, 1.0, 1.0, 1.0),
#   'Nitrogen': (0.18, 0.34, 0.95, 1.0),
#   'Oxygen': (0.7, 0.0, 0.0, 1.0)},
#  'background_color': (1, 1, 1),
#  'verbose': True,
#  'render': True,
#  'save': '',
#  'executable': '/Applications/Blender.app/Contents/MacOS/Blender',
#  'script': '/Users/kbsezginel/kbs/git/angstrom/angstrom/visualize/blender_sequencer.py',
#  'pickle': 'temp-config.pkl'}

# %%
# Move and rename all to a single dir
os.makedirs('3d', exist_ok=True)
idx = 0
for drx in ['x', 'y', 'z']:
    for i in range(30):
        shutil.copy(f"{drx}/{i}.png", f'3d/{idx}.png')
        idx += 1

images = [f"3d/{i}.png" for i in range(90)]

blend.configure(images=images, vid_file='hexagonal-planar-3d', script='seq', verbose=True,
                executable=blend.config['executable'], background_color=(1, 1, 1))
blend.config["fps"] = 17
blend.config["background_color"] = (1.0,1.0,1.0)
blend.config["resolution"] = (800, 800)
blend.config["executable"] = '/Applications/Blender.app/Contents/MacOS/Blender'
blend.run()
# Out:
# Stdout:
#
# Blender 2.81 (sub 16) (hash f1aa4d18d49d built 2019-12-04 14:33:18)
# Read prefs: /Users/kbsezginel/Library/Application Support/Blender/2.81/config/userpref.blend
# found bundled python: /Applications/Blender.app/Contents/Resources/2.81/python
# Created avi: hexagonal-planar-3d0001-0090.avi
# Fra:1 Mem:16.65M (0.00M, Peak 19.09M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:1 Mem:16.65M (0.00M, Peak 19.09M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 1
#  Time: 00:00.47 (Saving: 00:00.45)
#
# Fra:2 Mem:16.66M (0.00M, Peak 25.38M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:2 Mem:16.66M (0.00M, Peak 25.38M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 2
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:3 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:3 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 3
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:4 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:4 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 4
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:5 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:5 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 5
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:6 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:6 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 6
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:7 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:7 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 7
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:8 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:8 Mem:16.66M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 8
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:9 Mem:16.67M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:9 Mem:16.67M (0.00M, Peak 25.39M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 9
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:10 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:10 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 10
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:11 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:11 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 11
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:12 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:12 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 12
#  Time: 00:00.06 (Saving: 00:00.04)
#
# Fra:13 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:13 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 13
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:14 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:14 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 14
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:15 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:15 Mem:16.67M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 15
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:16 Mem:16.68M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:16 Mem:16.68M (0.00M, Peak 25.40M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 16
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:17 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:17 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 17
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:18 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:18 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 18
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:19 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:19 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 19
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:20 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:20 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 20
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:21 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:21 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 21
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:22 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:22 Mem:16.68M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 22
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:23 Mem:16.69M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:23 Mem:16.69M (0.00M, Peak 25.41M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 23
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:24 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:24 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 24
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:25 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:25 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 25
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:26 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:26 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 26
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:27 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:27 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 27
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:28 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:28 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 28
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:29 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:29 Mem:16.69M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 29
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:30 Mem:16.70M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:30 Mem:16.70M (0.00M, Peak 25.42M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 30
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:31 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:31 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 31
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:32 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:32 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 32
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:33 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:33 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 33
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:34 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:34 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 34
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:35 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:35 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 35
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:36 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:36 Mem:16.70M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 36
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:37 Mem:16.71M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:37 Mem:16.71M (0.00M, Peak 25.43M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 37
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:38 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:38 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 38
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:39 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:39 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 39
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:40 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:40 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 40
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:41 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:41 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 41
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:42 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:42 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 42
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:43 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:43 Mem:16.71M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 43
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:44 Mem:16.72M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:44 Mem:16.72M (0.00M, Peak 25.44M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 44
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:45 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:45 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 45
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:46 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:46 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 46
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:47 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:47 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 47
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:48 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:48 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 48
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:49 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:49 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 49
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:50 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:50 Mem:16.72M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 50
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:51 Mem:16.73M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:51 Mem:16.73M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 51
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:52 Mem:16.73M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:52 Mem:16.73M (0.00M, Peak 25.45M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 52
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:53 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:53 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 53
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:54 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:54 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 54
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:55 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:55 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 55
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:56 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:56 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 56
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:57 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:57 Mem:16.73M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 57
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:58 Mem:16.74M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:58 Mem:16.74M (0.00M, Peak 25.46M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 58
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:59 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:59 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 59
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:60 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:60 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 60
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:61 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:61 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 61
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:62 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:62 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 62
#  Time: 00:00.06 (Saving: 00:00.04)
#
# Fra:63 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:63 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 63
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:64 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:64 Mem:16.74M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 64
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:65 Mem:16.75M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:65 Mem:16.75M (0.00M, Peak 25.47M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 65
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:66 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:66 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 66
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:67 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:67 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 67
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:68 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:68 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 68
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:69 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:69 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 69
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:70 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:70 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 70
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:71 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:71 Mem:16.75M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 71
#  Time: 00:00.06 (Saving: 00:00.04)
#
# Fra:72 Mem:16.76M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:72 Mem:16.76M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 72
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:73 Mem:16.76M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:73 Mem:16.76M (0.00M, Peak 25.48M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 73
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:74 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:74 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 74
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:75 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:75 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 75
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:76 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.02 | Sce:  Ve:0 Fa:0 La:0
# Fra:76 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.02 | Sce:  Ve:0 Fa:0 La:0
# Append frame 76
#  Time: 00:00.06 (Saving: 00:00.04)
#
# Fra:77 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:77 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 77
#  Time: 00:00.06 (Saving: 00:00.04)
#
# Fra:78 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:78 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 78
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:79 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:79 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 79
#  Time: 00:00.06 (Saving: 00:00.04)
#
# Fra:80 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:80 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 80
#  Time: 00:00.05 (Saving: 00:00.04)
#
# Fra:81 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:81 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 81
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:82 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:82 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 82
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:83 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:83 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 83
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:84 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:84 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 84
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:85 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:85 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 85
#  Time: 00:00.05 (Saving: 00:00.03)
#
# Fra:86 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:86 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 86
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:87 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:87 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 87
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:88 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:88 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 88
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:89 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:89 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 89
#  Time: 00:00.04 (Saving: 00:00.03)
#
# Fra:90 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Fra:90 Mem:16.76M (0.00M, Peak 25.49M) | Time:00:00.01 | Sce:  Ve:0 Fa:0 La:0
# Append frame 90
#  Time: 00:00.05 (Saving: 00:00.03)
#
# {'pdb': {'filepath': '', 'use_center': True, 'use_camera': False, 'use_light': False, 'ball': '0', 'mesh_azimuth': 32, 'mesh_zenith': 32, 'scale_ballradius': 0.5, 'scale_distances': 1, 'atomradius': '2', 'use_sticks': True, 'use_sticks_type': '0', 'sticks_subdiv_view': 2, 'sticks_subdiv_render': 2, 'sticks_sectors': 20, 'sticks_radius': 0.25, 'sticks_unit_length': 0.05, 'use_sticks_color': True, 'use_sticks_smooth': True, 'use_sticks_bonds': False, 'sticks_dist': 1.1, 'use_sticks_one_object': True, 'use_sticks_one_object_nr': 200}, 'img_file': '', 'img_format': 'PNG', 'vid_file': 'hexagonal-planar-3d', 'vid_format': 'AVI_JPEG', 'images': ['3d/0.png', '3d/1.png', '3d/2.png', '3d/3.png', '3d/4.png', '3d/5.png', '3d/6.png', '3d/7.png', '3d/8.png', '3d/9.png', '3d/10.png', '3d/11.png', '3d/12.png', '3d/13.png', '3d/14.png', '3d/15.png', '3d/16.png', '3d/17.png', '3d/18.png', '3d/19.png', '3d/20.png', '3d/21.png', '3d/22.png', '3d/23.png', '3d/24.png', '3d/25.png', '3d/26.png', '3d/27.png', '3d/28.png', '3d/29.png', '3d/30.png', '3d/31.png', '3d/32.png', '3d/33.png', '3d/34.png', '3d/35.png', '3d/36.png', '3d/37.png', '3d/38.png', '3d/39.png', '3d/40.png', '3d/41.png', '3d/42.png', '3d/43.png', '3d/44.png', '3d/45.png', '3d/46.png', '3d/47.png', '3d/48.png', '3d/49.png', '3d/50.png', '3d/51.png', '3d/52.png', '3d/53.png', '3d/54.png', '3d/55.png', '3d/56.png', '3d/57.png', '3d/58.png', '3d/59.png', '3d/60.png', '3d/61.png', '3d/62.png', '3d/63.png', '3d/64.png', '3d/65.png', '3d/66.png', '3d/67.png', '3d/68.png', '3d/69.png', '3d/70.png', '3d/71.png', '3d/72.png', '3d/73.png', '3d/74.png', '3d/75.png', '3d/76.png', '3d/77.png', '3d/78.png', '3d/79.png', '3d/80.png', '3d/81.png', '3d/82.png', '3d/83.png', '3d/84.png', '3d/85.png', '3d/86.png', '3d/87.png', '3d/88.png', '3d/89.png'], 'fps': 17, 'camera': {'location': [0, 0, 10], 'rotation': [0, 0, 0], 'type': 'ORTHO', 'zoom': 20}, 'light': 2000.0, 'resolution': (800, 800), 'colors': {'Carbon': (0.05, 0.05, 0.05, 1.0), 'Hydrogen': (1.0, 1.0, 1.0, 1.0), 'Nitrogen': (0.18, 0.34, 0.95, 1.0), 'Oxygen': (0.7, 0.0, 0.0, 1.0)}, 'background_color': (1.0, 1.0, 1.0), 'verbose': True, 'render': True, 'save': '', 'executable': '/Applications/Blender.app/Contents/MacOS/Blender', 'script': '/Users/kbsezginel/kbs/git/angstrom/angstrom/visualize/blender_sequencer.py', 'pickle': 'temp-config.pkl'}
# Error: Not freed memory blocks: 6, total unfreed memory 0.003540 MB
#
# Blender quit
#
# Stderr:
